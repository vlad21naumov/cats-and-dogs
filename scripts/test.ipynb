# %%
from check_data_size import get_size

# %load_ext autoreload
# %autoreload 2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from download_data import get_size
#       3 get_ipython().run_line_magic('load_ext', 'autoreload')
#       4 get_ipython().run_line_magic('autoreload', '2')
#
# ImportError: cannot import name 'get_size' from 'download_data' (/Users/vl.naumov/Desktop/courses/mlops_course/cats-and-dogs/scripts/download_data.py)
