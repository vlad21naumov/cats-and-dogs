# %%
from check_data_size import get_size

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
get_size()
# Out:
#     1250

# %%
from download_data import download_and_extract

# %%
help(download_and_extract)
# Out:
# Help on function download_and_extract in module download_data:
#
# download_and_extract(url: str, target_dir: str) -> None
#     Downloads a ZIP file from a URL using wget, extracts it using unzip,
#     and deletes the ZIP file after extraction.

# %%
print(download_and_extract.__doc__)
# Out:
# Downloads a ZIP file from a URL using wget, extracts it using unzip,
#     and deletes the ZIP file after extraction.
